# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sklearn

# %%
df = pd.read_csv("/home/ridwan/Documents/canada_per_capita_income.csv")
df.head()
# Out:
#    year       Income
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('Income')
plt.scatter(df.year,df.Income,color='red')
